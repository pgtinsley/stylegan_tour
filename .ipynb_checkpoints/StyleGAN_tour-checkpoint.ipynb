# %%
# Let's go on a tour of the StyleGAN latent space.

# %%
# First things first...

import cv2
import random
import pandas as pd
import statistics

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Taken from pretrained_example.py
import os
import pickle
import PIL.Image
import numpy as np
import dnnlib
import dnnlib.tflib as tflib
import config
from encoder.generator_model import Generator

# Off-the-shelf recognizer
import face_recognition

# Plotting
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image, ImageDraw, ImageFont

# %%
# Plot latent vectors of shape 18x512
def generate_image(latent_vector):
    latent_vector = latent_vector.reshape((1, 18, 512))
    generator.set_dlatents(latent_vector)
    img_array = generator.generate_images()[0]
    img = PIL.Image.fromarray(img_array, 'RGB')
    return img.resize((1024, 1024))

# %%
def setup():
    tflib.init_tf()
    # Load pre-trained network.
    url = 'https://drive.google.com/uc?id=1MEGjdvVpUsu1jB4zrXZN7Y4kBBOzizDQ' # karras2019stylegan-ffhq-1024x1024.pkl
    with dnnlib.util.open_url(url, cache_dir=config.cache_dir) as f:
        _G, _D, Gs = pickle.load(f)
    generator = Generator(Gs, batch_size=1, randomize_noise=False) # -- RUNNING >1 TIMES THROWS ERROR
    fmt = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
    return [_G, _D, Gs, generator, fmt]

# %%
# Only run once.
[_G, _D, Gs, generator, fmt] = setup()

# %%
# Load in latent vectors
vec1 = np.load('latent_representations/pat_flynn_01.npy')
vec2 = np.load('latent_representations/kevin_bowyer_01.npy')
vec3 = np.load('latent_representations/walter_scheirer_01.npy')
# vec4 = np.load('latent_representations/arnold_schwarzenegger_01.npy')

# %%
# print(vec1.shape)

# %%
# Note for later: Is there a way to determine how well the encoder will encode the image originally fed in?

# %%
# zero_chick = generate_image(np.zeros(vec1.shape))
# zero_chick

# %%
# def change_identities(lat_vec1, lat_vec2, steps=60, fname='change_identities.avi'):
    
#     ### help ### 
#     ### https://gist.github.com/matpalm/23dc5804c6d673b800093d0d15e5de0e (author: mat kelcey) ###
 
#     lat_vec1_slim = np.reshape(lat_vec1, [1, lat_vec1.shape[0] * lat_vec1.shape[1]])
#     lat_vec2_slim = np.reshape(lat_vec2, [1, lat_vec2.shape[0] * lat_vec2.shape[1]])
    
#     assert(lat_vec1_slim.shape == lat_vec2_slim.shape, 'Latent vectors have different shape.')
    
#     z = np.empty((steps, lat_vec1_slim.shape[1]))   
#     for i, alpha in enumerate(np.linspace(start=1.0, stop=0.0, num=steps)):
#         z[i] = alpha * lat_vec1_slim + (1.0-alpha) * lat_vec2_slim
 
#     ### end help ###

#     images = []
#     for i in range(steps):
#         curr_vec = np.reshape(z[i], [18, 512]) # back to original shape
#         curr_img = generate_image(curr_vec)
#         images.append(np.array(curr_img))
        
#     s = images[0].shape
#     videowriter =  cv2.VideoWriter(fname, cv2.VideoWriter_fourcc(*'mp4v'), steps/10, (s[1], s[0]))
#     for i in range(len(images)):
#         videowriter.write(images[i][...,::-1])
#     videowriter.release()

# %%
## From PF --> KB
# change_identities(vec1, vec2, steps=60, fname='pf_to_kb.avi')

# %%
## From 0 --> PF
# change_identities(np.zeros(vec1.shape), vec1, steps=90, fname='zero_to_pf.avi')

# %%
## From KB --> PF 
# change_identities(vec2, vec1, steps=60, fname='kb_to_pf.avi')

# %%
# SECOND HALF -- Which of the 18 vectors are identity salient?

# %%
# Let's mess around with KB...

# %%
def perturb_vector_axis(vector=vec1, num_images=60, axis=0, vid_fname='videos/test_video.avi'):

    # Get base image.
    base_img = generate_image(vector)
    # Get base image face encoding.
    base_face_encoding = face_recognition.face_encodings(np.array(base_img))[0]

    # Set up lists.    
    perts = []
    
    sg_distances = []
    fr_distances = []
    
    face_match = []

    # Set up video.
    s = np.array(base_img).shape
    videowriter =  cv2.VideoWriter(vid_fname, cv2.VideoWriter_fourcc(*'mp4v'), 5, (s[1], s[0]))
    
    for i in range(num_images):

        # Copy original vector
        vector_copy = np.copy(vector)

        # Perturb vector copy at specified axis.
        rnd = np.random.RandomState(i)
        pert = rnd.randn(Gs.input_shape[1])
        vector_copy[axis] = vector_copy[axis] + pert

        # Track vector perturbances for later analysis.
        perts.append(pert)

        # Track distance between vectors in sg latent space.
        sg_distances.append(np.linalg.norm(vector_copy - vector))
        # np.linalg.norm(vector_copy - vector) is Euclidean distance between base vector and perturbed vector.

        # Get perturbed image.
        perturbed_img = generate_image(vector_copy)
        # Get perturbed image face encoding.
        perturbed_face_encodings = face_recognition.face_encodings(np.array(perturbed_img))

        ### Found a face.
        if len(perturbed_face_encodings) > 0:
            perturbed_face_encoding = perturbed_face_encodings[0]
            fr_dist = face_recognition.face_distance([base_face_encoding], perturbed_face_encoding)[0]
            match = fr_dist < 0.4
            face_match.append(str(match)) # IS FOUND FACE CLOSE ENOUGH?

        ### Did NOT find a face.
        else:
            fr_dist = 1.0
            match = 'No Face Found'
            face_match.append(match) # NO FACE FOUND

        # Track distance between encodings in face_recognition space.
        fr_distances.append(fr_dist)
        
        # Write on image.
        draw = ImageDraw.Draw(perturbed_img)
        font = ImageFont.truetype('./fonts/GeosansLight.ttf', 40)
        col = 'green' if match==True else 'red'
        draw.text((40, 40), 'Face Match: '+str(match), font=font, fill=col)
        
        # Write image to video.
        videowriter.write(np.array(perturbed_img)[...,::-1])

    # Release handle.
    videowriter.release()
    
    # Save data in pandas df.
    df = pd.DataFrame([perts, sg_distances, fr_distances, face_match]).transpose()
    df.columns = ['perturbances', 'sg_distances', 'fr_distances', 'face_match']

    # To send back to user.
    return_dict = {}
    return_dict['df'] = df
    return_dict['vector'] = vector
    return_dict['axis'] = axis
    return_dict['base_image'] = base_img
    return_dict['base_face_encoding'] = base_face_encoding
    
    return return_dict

# %% [markdown]
# # exp1
#
# Let's make sure that the number of False matches in face_match decreases as axis increases.
#
# i.e. Let's see if the finer 'knobs' don't change as much in the face_recognition space.

# %%
# # This is just for one vector (vec2 = KB) ... 
# # We need to run this with more subjects obviously.
# all_axes_dict = {}
# for a in range(18):
#     print('Running axis '+str(a)+'.')
#     axis_dict = perturb_vector_axis(vector=vec2, axis=a, vid_fname='videos/exp1_vec2_axis'+str(a)+'.avi')
#     all_axes_dict[a] = axis_dict

# %%
# with open('all_axes_dict.pickle', 'wb') as f:
#     pickle.dump(all_axes_dict, f)

# %%
with open('pickles/all_axes_dict_vec1.pickle', 'rb') as f:
    all_axes_dict_vec1 = pickle.load(f)

# %%
with open('pickles/all_axes_dict_vec2.pickle', 'rb') as f:
    all_axes_dict_vec2 = pickle.load(f)

# %%
with open('pickles/all_axes_dict_vec3.pickle', 'rb') as f:
    all_axes_dict_vec3 = pickle.load(f)

# %%
axes = range(18)

# %%
miss_rates1 = []
mean_fr_distances1 = []

for a in axes:
    
    axis_dict = all_axes_dict_vec1[a]
    tmpdf = axis_dict['df']
    
    mean_fr_distances1.append(np.mean(tmpdf['fr_distances']))
    
    vc = tmpdf['face_match'].value_counts()
    
    if 'True' not in vc.index:
        miss_rate = 1.0
    else:
        miss_rate = 1.0 - (vc['True']/len(tmpdf))
    
    # print('Axis {}:\n{}\nmiss_rate={}\n'.format(a, vc, miss_rate))
    miss_rates1.append(miss_rate)

# %%
miss_rates2 = []
mean_fr_distances2 = []

for a in axes:
    
    axis_dict = all_axes_dict_vec2[a]
    tmpdf = axis_dict['df']
    
    mean_fr_distances2.append(np.mean(tmpdf['fr_distances']))
    
    vc = tmpdf['face_match'].value_counts()
    
    if 'True' not in vc.index:
        miss_rate = 1.0
    else:
        miss_rate = 1.0 - (vc['True']/len(tmpdf))
    
    # print('Axis {}:\n{}\nmiss_rate={}\n'.format(a, vc, miss_rate))
    miss_rates2.append(miss_rate)

# %%
miss_rates3 = []
mean_fr_distances3 = []

for a in axes:
    
    axis_dict = all_axes_dict_vec3[a]
    tmpdf = axis_dict['df']
    
    mean_fr_distances3.append(np.mean(tmpdf['fr_distances']))
    
    vc = tmpdf['face_match'].value_counts()
    
    if 'True' not in vc.index:
        miss_rate = 1.0
    else:
        miss_rate = 1.0 - (vc['True']/len(tmpdf))
    
    # print('Axis {}:\n{}\nmiss_rate={}\n'.format(a, vc, miss_rate))
    miss_rates3.append(miss_rate)

# %%
plt.title('Mean Face Distance \nas a Function of Perturbed Axis')

plt.xlabel('Perturbed Axis Index')
plt.ylabel('Distance in face_recognition Space')

plt.xticks(axes, axes)

plt.plot(axes, mean_fr_distances1, label='PF')
plt.plot(axes, mean_fr_distances2, label='KB')
plt.plot(axes, mean_fr_distances3, label='WS')
plt.hlines(y=0.4, xmin=min(axes), xmax=max(axes), colors='red')

plt.legend(loc='top right')

plt.show()

# %%
plt.title('Missed face_match Percentage \nas a Function of Perturbed Axis')

plt.xlabel('Perturbed Axis Index')
plt.ylabel('Missed face_match Percentage (#misses/60)')

plt.xticks(axes, axes)

plt.plot(axes, miss_rates1, label='PF')
plt.plot(axes, miss_rates2, label='KB')
plt.plot(axes, miss_rates3, label='WS')

plt.legend(loc='top right')

plt.show()

# %% [markdown]
# # exp2
#
# Investigate the True and False matches to see if we can do better than random substitution into the perturbed vector at the specified axis.

# %%
# all_axes_dict_vec1[0]

# %%
a = 0

# %%
tmpdf = all_axes_dict_vec1[a]['df']

# %%
tmpdf_true = tmpdf[tmpdf['face_match']=='True']
tmpdf_false = tmpdf[tmpdf['face_match']!='True']

# %%
vector = all_axes_dict_vec1[a]['vector'][a]

# %%
# len(vector)

# %%
tmpdf_true_split = pd.DataFrame(tmpdf_true.perturbances.tolist())

# %%
tmpdf_false_split = pd.DataFrame(tmpdf_false.perturbances.tolist())

# %%
dist_2d_true = []
for i, row in tmpdf_true_split.iterrows():
    dist_1d = [a_i - b_i for a_i, b_i in zip(row, vector)]
    dist_2d_true.append(dist_1d)

# %%
df_dist_true = pd.DataFrame(dist_2d_true)

# %%
dist_2d_false = []
for i, row in tmpdf_false_split.iterrows():
    dist_1d = [a_i - b_i for a_i, b_i in zip(row, vector)]
    dist_2d_false.append(dist_1d)

# %%
df_dist_false = pd.DataFrame(dist_2d_false)

# %%
means_true = []
stdevs_true = []
for colname, coldata in df_dist_true.iteritems():
    means_true.append(coldata.mean())
    stdevs_true.append(statistics.stdev(coldata))

# %%
means_false = []
stdevs_false = []
for colname, coldata in df_dist_false.iteritems():
    means_false.append(coldata.mean())
    stdevs_false.append(statistics.stdev(coldata))

# %%
pd.Series(means_true).plot(label='means true', alpha=0.5)
pd.Series(means_false).plot(label='means false', alpha=0.5)

# %%
pd.Series(stdevs_true).plot(label='stdev true', alpha=0.5)
pd.Series(stdevs_false).plot(label='stdev false', alpha=0.5)

# %% [markdown]
# # exp3

# %%
def perturb_vector_axis_gain(vector=vec1, num_images=60, axis=0, vid_fname='videos/test_video.avi'):

    # Get base image.
    base_img = generate_image(vector)
    # Get base image face encoding.
    base_face_encoding = face_recognition.face_encodings(np.array(base_img))[0]

    # Set up lists.    
    perts = []
    
    sg_distances = []
    fr_distances = []
    
    face_match = []

    # Set up video.
    s = np.array(base_img).shape
    videowriter =  cv2.VideoWriter(vid_fname, cv2.VideoWriter_fourcc(*'mp4v'), 5, (s[1], s[0]))
    
#     for i in range(num_images):
    for gain in np.linspace(-1,1,num_images): 
    # -1 and 1 will eventually be changed to be something subject-specific maybe

        # Copy original vector
        vector_copy = np.copy(vector)

#         # Perturb vector copy at specified axis.
#         rnd = np.random.RandomState(i)
#         pert = rnd.randn(Gs.input_shape[1])
#         vector_copy[axis] = vector_copy[axis] + pert
        
        pert = vector_copy[axis] + gain
        vector_copy[axis] = pert
    
        # Track vector perturbances for later analysis.
        perts.append(pert)

        # Track distance between vectors in sg latent space.
        sg_distances.append(np.linalg.norm(vector_copy - vector))
        # np.linalg.norm(vector_copy - vector) is Euclidean distance between base vector and perturbed vector.

        # Get perturbed image.
        perturbed_img = generate_image(vector_copy)
        # Get perturbed image face encoding.
        perturbed_face_encodings = face_recognition.face_encodings(np.array(perturbed_img))

        ### Found a face.
        if len(perturbed_face_encodings) > 0:
            perturbed_face_encoding = perturbed_face_encodings[0]
            fr_dist = face_recognition.face_distance([base_face_encoding], perturbed_face_encoding)[0]
            match = fr_dist < 0.4
            face_match.append(str(match)) # IS FOUND FACE CLOSE ENOUGH?

        ### Did NOT find a face.
        else:
            fr_dist = 1.0
            match = 'No Face Found'
            face_match.append(match) # NO FACE FOUND

        # Track distance between encodings in face_recognition space.
        fr_distances.append(fr_dist)
        
        # Write on image.
        draw = ImageDraw.Draw(perturbed_img)
        font = ImageFont.truetype('./fonts/GeosansLight.ttf', 40)
        col = 'green' if match==True else 'red'
        draw.text((40, 40), 'Face Match: '+str(match), font=font, fill=col)
        
        # Write image to video.
        videowriter.write(np.array(perturbed_img)[...,::-1])

    # Release handle.
    videowriter.release()
    
    # Save data in pandas df.
    df = pd.DataFrame([perts, sg_distances, fr_distances, face_match]).transpose()
    df.columns = ['perturbances', 'sg_distances', 'fr_distances', 'face_match']

    # To send back to user.
    return_dict = {}
    return_dict['df'] = df
    return_dict['vector'] = vector
    return_dict['axis'] = axis
    return_dict['base_image'] = base_img
    return_dict['base_face_encoding'] = base_face_encoding
    
    return return_dict

# %%
all_axes_dict = {}
for a in range(18):
    print('Running axis '+str(a)+'.')
    axis_dict = perturb_vector_axis(vector=vec1, axis=a, vid_fname='videos/exp3_vec1_axis'+str(a)+'.avi')
    all_axes_dict[a] = axis_dict
# Out:
# Running axis 0.
# Running axis 1.
# Running axis 2.
# Running axis 3.
# Running axis 4.
# Running axis 5.
# Running axis 6.
# Running axis 7.
# Running axis 8.
# Running axis 9.
# Running axis 10.
# Running axis 11.
# Running axis 12.
# Running axis 13.
# Running axis 14.
# Running axis 15.
# Running axis 16.
# Running axis 17.

# %%
# with open('pickles/exp3/all_axes_dict_vec1.pickle', 'wb') as f:
#     pickle.dump(all_axes_dict, f)

# %%
miss_rates1 = []
mean_fr_distances1 = []

axes=range(18)
for a in axes:
    
    axis_dict = all_axes_dict[a]
    tmpdf = axis_dict['df']
    
    mean_fr_distances1.append(np.mean(tmpdf['fr_distances']))
    
    vc = tmpdf['face_match'].value_counts()
    
    if 'True' not in vc.index:
        miss_rate = 1.0
    else:
        miss_rate = 1.0 - (vc['True']/len(tmpdf))
    
    # print('Axis {}:\n{}\nmiss_rate={}\n'.format(a, vc, miss_rate))
    miss_rates1.append(miss_rate)

# %%
plt.title('Mean Face Distance \nas a Function of Perturbed Axis')

plt.xlabel('Perturbed Axis Index')
plt.ylabel('Distance in face_recognition Space')

plt.xticks(axes, axes)

plt.plot(axes, mean_fr_distances1, label='PF')

plt.hlines(y=0.4, xmin=min(axes), xmax=max(axes), colors='red')

plt.legend(loc='top right')

plt.show()

# %%
plt.title('Missed face_match Percentage \nas a Function of Perturbed Axis')

plt.xlabel('Perturbed Axis Index')
plt.ylabel('Missed face_match Percentage (#misses/60)')

plt.xticks(axes, axes)

plt.plot(axes, miss_rates1, label='PF')

plt.legend(loc='top right')

plt.show()
